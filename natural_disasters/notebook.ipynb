# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's take a lot at the data.

# %%
df = pd.read_csv("data/train.csv", index_col = ["id"])
df.head()
# Out:
#    keyword location                                               text  target
# id
# 1      NaN      NaN  Our Deeds are the Reason of this #earthquake M...       1
# 4      NaN      NaN             Forest fire near La Ronge Sask. Canada       1
# 5      NaN      NaN  All residents asked to 'shelter in place' are ...       1
# 6      NaN      NaN  13,000 people receive #wildfires evacuation or...       1
# 7      NaN      NaN  Just got sent this photo from Ruby #Alaska as ...       1

# %%
df.info()
# df["keyword"].value_counts()
#df["location"].value_counts()
#df["target"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7613 entries, 1 to 10873
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   keyword   7552 non-null   object
#  1   location  5080 non-null   object
#  2   text      7613 non-null   object
#  3   target    7613 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 297.4+ KB

# %%
X_train = df.drop(["target"], axis = 1)
y_train = df["target"]

# %%
X_train.sample(78)
# Out:
#           keyword               location  \
# id
# 9365     survived               Polmont
# 6246    hijacking                  China
# 5029   eyewitness    Somewhere in Jersey
# 2920       danger            St Paul, MN
# 7010       mayhem                    NaN
# ...           ...                    ...
# 10581   windstorm                Chicago
# 4079    displaced            Oakland, CA
# 4864      explode   |IG: imaginedragoner
# 3089       deaths        the void, U.S.A
# 7345   obliterate              Dover, DE
#
#                                                     text
# id
# 9365   Just burst out in actual tears of joy when Cai...
# 6246   #hot  Funtenna: hijacking computers to send da...
# 5029   I liked a @YouTube video http://t.co/YdgiUYdqg...
# 2920   Training grains of wheat to bare gold in the A...
# 7010                                 Mayhem is beautiful
# ...                                                  ...
# 10581  'My Fifty Online Dates and why I'm still singl...
# 4079   Historic flooding across Asia leaves hundreds ...
# 4864   If Ryan doesn't release new music soon I might...
# 3089   @HighQualityBird a reverse situation (lol I do...
# 7345   @dicehateme @PuppyShogun This makes sense. Pap...
#
# [78 rows x 3 columns]

# %%
df["keyword"] = df["keyword"].astype(str)
df["keyword"].replace(to_replace="%20",value = " ", inplace =True, regex = True)

# %%
df["keyword"].sample(5)
# Out:
# id
# 4377     earthquake
# 10793       wrecked
# 5157          fatal
# 5052     eyewitness
# 8171       rescuers
# Name: keyword, dtype: object

# %%
import string
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

def preprocessing(sentence):
    sentence.strip(" ")
    for punctuation in string.punctuation:
         sentence = sentence.replace(punctuation, '')
    for c in sentence:
        sentence.lower()
    sentence = ''.join(char for char in sentence if not char.isdigit())
    tokenized_sentence = word_tokenize(sentence)
    lemmatized = [
        WordNetLemmatizer().lemmatize(word, pos = "v") 
        for word in tokenized_sentence
    ]
    lemmatized = " ".join(lemmatized) 
    return lemmatized

# %%
X_train["keyword"] = df["keyword"].apply(preprocessing)
X_train["text"] = df["text"].apply(preprocessing)

# %%
X_train["keyword"].sample(10)
# Out:
# id
# 10704                 wreck
# 5506                  flame
# 3016                  death
# 5002              explosion
# 2215     chemical emergency
# 67                   ablaze
# 9465              terrorism
# 5505                  flame
# 3676                destroy
# 9813                 trauma
# Name: keyword, dtype: object

# %% [markdown]
# Let's make a function that:
# 1) Get's all keyword values in a list.
# 2) For each "nan" if corresponding df["text"] in list df["keyword"] replace.

# %%
values = list(X_train["keyword"].unique())

# %%
for index, row in X_train.iterrows():
    word_list = row["text"].split(" ")
    if row["keyword"] == "nan":
        for word in word_list:
            if word in values:
                row["keyword"] = word

# %%
X_train.head(50)
# Out:
#        keyword                       location  \
# id
# 1   earthquake                            NaN
# 4         fire                            NaN
# 5   evacuation                            NaN
# 6   evacuation                            NaN
# 7        smoke                            NaN
# 8         fire                            NaN
# 10       flood                            NaN
# 13        fire                            NaN
# 14  evacuation                            NaN
# 15     tornado                            NaN
# 16         nan                            NaN
# 17       flood                            NaN
# 18       flood                            NaN
# 19         nan                            NaN
# 20       crash                            NaN
# 23         nan                            NaN
# 24         nan                            NaN
# 25         nan                            NaN
# 26         nan                            NaN
# 28         nan                            NaN
# 31         nan                            NaN
# 32         nan                            NaN
# 33         nan                            NaN
# 34         nan                            NaN
# 36         nan                            NaN
# 37         nan                            NaN
# 38         nan                            NaN
# 39         nan                            NaN
# 40         nan                            NaN
# 41         nan                            NaN
# 44         nan                            NaN
# 48      ablaze                     Birmingham
# 49      ablaze  Est. September 2012 - Bristol
# 50      ablaze                         AFRICA
# 52      ablaze               Philadelphia, PA
# 53      ablaze                     London, UK
# 54      ablaze                       Pretoria
# 55      ablaze                   World Wide!!
# 56      ablaze                            NaN
# 57      ablaze                 Paranaque City
# 59      ablaze                 Live On Webcam
# 61      ablaze                            NaN
# 62      ablaze                      milky way
# 63      ablaze                            NaN
# 64      ablaze                            NaN
# 65      ablaze                            NaN
# 66      ablaze      GREENSBORO,NORTH CAROLINA
# 67      ablaze                            NaN
# 68      ablaze                 Live On Webcam
# 71      ablaze                       England.
#
#                                                  text
# id
# 1   Our Deeds be the Reason of this earthquake May...
# 4               Forest fire near La Ronge Sask Canada
# 5   All residents ask to shelter in place be be no...
# 6   people receive wildfires evacuation order in C...
# 7   Just get send this photo from Ruby Alaska as s...
# 8   RockyFire Update California Hwy close in both ...
# 10  flood disaster Heavy rain cause flash flood of...
# 13  Im on top of the hill and I can see a fire in ...
# 14  Theres an emergency evacuation happen now in t...
# 15     Im afraid that the tornado be come to our area
# 16         Three people die from the heat wave so far
# 17  Haha South Tampa be get flood hah WAIT A SECON...
# 18  rain flood Florida TampaBay Tampa or days Ive ...
# 19               Flood in Bago Myanmar We arrive Bago
# 20  Damage to school bus on in multi car crash BRE...
# 23                                       Whats up man
# 24                                       I love fruit
# 25                                   Summer be lovely
# 26                                  My car be so fast
# 28                             What a goooooooaaaaaal
# 31                                 this be ridiculous
# 32                                     London be cool
# 33                                           Love ski
# 34                               What a wonderful day
# 36                                           LOOOOOOL
# 37                         No wayI cant eat that shit
# 38                               Was in NYC last week
# 39                                 Love my girlfriend
# 40                                             Cooool
# 41                                  Do you like pasta
# 44                                            The end
# 48   bbcmtd Wholesale Markets ablaze httptcolHYXEOHYC
# 49  We always try to bring the heavy metal RT http...
# 50  AFRICANBAZE Breaking newsNigeria flag set abla...
# 52                  Crying out for more Set me ablaze
# 53  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...
# 54  PhDSquares mufc theyve build so much hype arou...
# 55    INEC Office in Abia Set Ablaze httptcoImaomknnA
# 56  Barbados Bridgetown JAMAICA ÛÒ Two cars set a...
# 57                              Ablaze for you Lord D
# 59  Check these out httptcorOINSmEJJ httptcoTjZjiN...
# 61  on the outside youre ablaze and alive but your...
# 62  Had an awesome time visit the CFC head office ...
# 63             SOOOO PUMPED FOR ABLAZE southridgelife
# 64  I want to set Chicago ablaze with my preach Bu...
# 65  I gain followers in the last week You Know you...
# 66  How the West be burn Thousands of wildfires ab...
# 67  Building the perfect tracklist to life leave t...
# 68  Check these out httptcorOINSmEJJ httptcoTjZjiN...
# 71  First night with retainers in Its quite weird ...

# %%
X_train.head()
# Out:
#    keyword location                                               text
# id
# 1       []      NaN  Our Deeds be the Reason of this earthquake May...
# 4       []      NaN              Forest fire near La Ronge Sask Canada
# 5       []      NaN  All residents ask to shelter in place be be no...
# 6       []      NaN  people receive wildfires evacuation order in C...
# 7       []      NaN  Just get send this photo from Ruby Alaska as s...
